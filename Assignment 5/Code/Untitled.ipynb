# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
n=[5000,10000,50000,100000]
seq=[0.000037,0.000060,0.000262,0.000475,]
static=[0.000047, 0.000091,0.000161,0.000327]
static_chunk=[0.000050, 0.000065,0.000153,  0.000387]
dynamic_chunk=[0.000055, 0.000126,0.000196,  0.000401]
guided=[0.000071, 0.000099, 0.000167, 0.000454]
runtime=[ 0.000084,0.000101,0.000239,0.000431]

# %%
plt.figure(figsize=(20,11))
plt.plot(n,seq,label="Sequential")
plt.plot(n,static,label="static")
plt.plot(n,static_chunk,label="static_chunk")
plt.plot(n,dynamic_chunk,label="dynamic_chunk")
plt.plot(n,guided,label="guided")
plt.plot(n,runtime,label="runtime")
plt.xlabel("N")
plt.ylabel("Time")
plt.legend()
plt.show()
